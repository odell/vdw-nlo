# %%
import numpy as np
import matplotlib.pyplot as plt
import gao

# %%
roots = np.loadtxt('datfiles/roots0.dat', dtype=np.complex128)

# %%
plt.plot(roots[:, 0], roots[:, 1].imag)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
gao.find_nu(0, -1, gao.nu_0(0))
# Out:
# (0.6470040448386326+0j)

# %%
c6 = 835.9
β6 = (c6)**0.25
mass = 1

# %%
ds = np.linspace(-400, 0, 500)
chis = np.array([chi(d, 0, 0.1, c6) for d in ds])
# Out:
# /home/odell/Documents/vdw/src/Gao/gao_sols.py:181: RuntimeWarning: invalid value encountered in double_scalars
#   diff = max(np.abs((sum-last)/last), np.abs((last-last2)/last2))
# /home/odell/Documents/vdw/src/Gao/gao_sols.py:255: RuntimeWarning: divide by zero encountered in double_scalars
#   return np.abs(Del)**(-nu) * gamma(1+nu0(l)+nu)*gamma(1-nu0(l)+nu)/gamma(1-nu) * C(nu, l, Del)
# /home/odell/Documents/vdw/src/Gao/gao_sols.py:263: RuntimeWarning: invalid value encountered in double_scalars
#   return ((a*np.sin(np.pi*nu) - b*np.cos(np.pi*nu))*Gminus + b*Gplus) / ((b*np.sin(np.pi*nu) + a*np.cos(np.pi*nu))*Gminus - a*Gplus)

# %%
plt.figure()
plt.plot(ds, chis)
plt.xlabel('$\Delta$')
plt.ylabel('$\chi_{l=0}$')
plt.ylim([-175, 125])
plt.xlim([-400, 0])
plt.axhline(25, color='r', linestyle='--')
plt.savefig('/home/odell/Dropbox/UT/Research/my-dissertation/figures/pdf/chi.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
data = np.loadtxt('datfiles/chi.dat')
ds = data[:, 0]
chis = data[:, 1]

plt.figure()
plt.ylim([-175, 125])
plt.xlim([-400, 0])
plt.axhline(25, color='r', linestyle='--')
plt.plot(ds, chis, color='b')
plt.savefig('/home/odell/Dropbox/UT/Research/my-dissertation/figures/pdf/chi.pdf')
# Out:
# <img src="data:image/png;base64,..." width="640">
