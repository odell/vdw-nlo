# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
from helium4plusplus import BETA6
from helium4plusplusminus import BETA6 as BETA6p

plt.style.use('science')

# %%
data = np.array([
    [2.77, 1.776734271030349e-01, -6.462806204504279e-02],
    [2.43, 1.420590282271789e-01, -1.377011640704686e-02],
    [2.15, 1.127250096760215e-01, 1.921534328308655e-02],
    [2.05, 1.016738609855964e-01, 4.413019281065396e-02],
    [1.93, 8.680613184812991e-02, 7.722594321548895e-01],
    [1.85, 7.983519728512875e-02, 1.318235508197901e-02],
    [1.73, 7.093229166187284e-02, -1.951022141696998e-02],
    [1.63, 6.526144202499759e-02, -6.303548874069621e-03],
    [1.53, 6.214388337507194e-02, -7.693399191626815e-04]
])

datap = np.array([
    [2.43, 1.568022867170179e-01, -3.595324473646055e-02],
    [2.23, 1.348825656957911e-01, -1.785383243269921e-02],
    [2.05, 1.134497896570379e-01, -4.672779220365597e-03],
    [1.95, 1.001724478561379e-01,  7.296640564123657e-03],
    [1.84, 8.781025368348526e-02, -2.249593173696911e-02],
    [1.73, 7.794480551771364e-02,  5.564806533972965e-03],
    [1.62, 7.064480497483953e-02,  1.172981229881385e-02],
    [1.53, 6.622121471575805e-02,  1.516183891424987e-02]
])

# %%
fig, ax = plt.subplots(dpi=200)
fig.patch.set_facecolor('white')

ax.plot(BETA6 / data[:, 0], data[:, 1] + data[:, 2], label=r'Increased $C_6$', marker='o', linestyle='')
ax.plot(BETA6p / datap[:, 0], datap[:, 1] + datap[:, 2], label=r'Physical $C_6$', marker='o', linestyle='')
ax.axhline(1.31e-3, color='C2', linestyle='--', label=r'$B_2$')

ax.legend()
ax.set_xlabel(r'$\beta_6/R$')
ax.set_ylabel(r'$B_3^{({\rm NLO})}$')
ax.set_yscale('log');
