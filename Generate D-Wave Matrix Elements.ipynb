# %% [markdown]
# # ${}^{4}{\rm He}$
#
# The interaction is defined in `helium4.py`. It is nonlocal, and so is the counterterm. We will use it to tune the scattering length, $a_0$, **and** the effective range, $r_0$, over a range of short-distance cutoffs, $R$.

# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt
import scienceplots
from tqdm import tqdm

import helium4plusplusminus as he4
import lm2m2

plt.style.use('science')
gr = 4/3
h = 3

# %%
# angular momentum
ELL = 2

# load lo coupling constants
Rs, c00s, c01s, c21s, _, _ = np.loadtxt('datfiles/rg_flows/rg-nlo-physicalC6-2.txt', unpack=True)
# number of short distance cutoffs
nR = Rs.size

# %%
index = 0
R = Rs[index]
c00 = c00s[index]
c01 = c01s[index]
c21 = c21s[index]

s = he4.NonlocalHelium4System2(R, ELL, 2, 6, 6)

# %%
momenta = np.linspace(0.01/he4.BETA6, 0.3/he4.BETA6, 30)
s.a0_and_r0_pert1b_fast(c00, c01, c21, momenta)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[4], line 2
#       1 momenta = np.linspace(0.01/he4.BETA6, 0.3/he4.BETA6, 30)
# ----> 2 s.a0_and_r0_pert1b_fast(c00, c01, c21, momenta)
#
# File ~/vdw-nlo/helium4plusplusminus.py:139, in NonlocalHelium4System2.a0_and_r0_pert1b_fast(self, c_00, c_01, c_21, ks, p0, return_sigma)
#     135 def a0_and_r0_pert1b_fast(self, c_00, c_01, c_21, ks, p0=None, return_sigma=False):
#     136     '''
#     137     Returns a_0 and r_0 after fitting the effective range parameters.
#     138     '''
# --> 139     assert self.ell == 0, 'This is not an S-wave (l = 0) system.'
#     140     kcds = self.kcotd_gen_pert1b_fast(ks, c_00, c_01, c_21)
#     141     result = optimize.curve_fit(
#     142         lambda x, c0, c2, c3: c0 + c2*x**2 + c3*x**3,
#     143         ks, kcds, p0=p0, maxfev=20000
#     144     )
#
# AssertionError: This is not an S-wave (l = 0) system.

# %%
for i in tqdm(range(nR)):
    R = Rs[i]
    s = he4.NonlocalHelium4System2(R, ELL, 2, 6, 6)
    with open(f'datfiles/matrix_elements/lo_d_wave/R_{R:.8e}_D_wave.txt', 'w+') as f:
        f.write('# weight[i] (1/Å)  momenta[i] (1/Å)  momenta[j] (1/Å)  v_0[i, j] (K•Å^3)\n')
        v0 = s.v_tilde
        for i in range(s.q.size):
            for j in range(s.q.size):
                f.write(f'{s.wq[i]:.8e}  {s.q[i]:.8e}  {s.q[j]:.8e}  {v0[i, j]:.8e}\n')
# Out:
# 100%|███████████████████████████████████████████| 67/67 [01:43<00:00,  1.55s/it]
